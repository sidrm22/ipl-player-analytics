# %%
import pandas as pd

# %%
matches=pd.read_csv("matches.csv") # Run each line and look at what comes back

# %%
deliveries=pd.read_csv("deliveries.csv")

# %%
deliveries.tail(10)
# Out:
#         match_id  inning           batting_team         bowling_team  over  \
# 260910   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad     8
# 260911   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad     9
# 260912   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad     9
# 260913   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad     9
# 260914   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad     9
# 260915   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad     9
# 260916   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad     9
# 260917   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad    10
# 260918   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad    10
# 260919   1426312       2  Kolkata Knight Riders  Sunrisers Hyderabad    10
#
#         ball   batter         bowler non_striker  batsman_runs  extra_runs  \
# ...

# %%
#matches.head(100)# first 5 rows
matches[matches['super_over'] == 'Y']
# Out:
#           id   season       city        date match_type player_of_match  \
# 66    392190     2009  Cape Town  2009-04-23     League       YK Pathan
# 130   419121  2009/10    Chennai  2010-03-21     League        J Theron
# 328   598004     2013  Hyderabad  2013-04-07     League       GH Vihari
# 342   598017     2013  Bangalore  2013-04-16     League         V Kohli
# 416   729315     2014  Abu Dhabi  2014-04-29     League     JP Faulkner
# 475   829741     2015  Ahmedabad  2015-04-21     League        SE Marsh
# 610  1082625     2017     Rajkot  2017-04-29     League       KH Pandya
# 705  1175365     2019      Delhi  2019-03-30     League         PP Shaw
# 746  1178426     2019     Mumbai  2019-05-02     League       JJ Bumrah
# 757  1216493  2020/21        NaN  2020-09-20     League      MP Stoinis
# 765  1216547  2020/21        NaN  2020-09-28     League  AB de Villiers
# 790  1216512  2020/21  Abu Dhabi  2020-10-18     League     LH Ferguson
# ...

# %%
matches.shape # rows and columns count
# Out:
# (1095, 20)

# %%
matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
matches.info() # data types and missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
# ...

# %%
matches.describe()  # basic statistics
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.095000e+03    1076.000000  1092.000000   1092.000000
# mean   9.048283e+05      17.259294   165.684066     19.759341
# std    3.677402e+05      21.787444    33.427048      1.581108
# min    3.359820e+05       1.000000    43.000000      5.000000
# 25%    5.483315e+05       6.000000   146.000000     20.000000
# 50%    9.809610e+05       8.000000   166.000000     20.000000
# 75%    1.254062e+06      20.000000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %%
#Q1 How many IPL seasons does this data cover?
print(matches['season'].nunique())
# Out:
# 17

# %%
#Q2 How many unique teams have played?
all_teams = pd.concat([matches['team1'], matches['team2']]).unique()
print(len(all_teams))
# Out:
# 19

# %%
#Q3Which columns have missing/null values?
# city(51), player_of_match(5), winner(5), result_margin(19), method(1074)
# method is mostly null because DLS method is rarely used — that's fine

# %%
#Q4 What does one row in deliveries.csv represent?

#A4 One row in deliveries = one ball bowled in a match

# %%
#Q5 How are matches.csv and deliveries.csv connected? 
#A5 Connected via: matches['id'] == deliveries['match_id']
print(matches['id'].iloc[0], deliveries['match_id'].iloc[0])
# Out:
# 335982 335982
